# %%
import pandas as pd
import numpy as np
import uuid

# %%
REAL_PATH = "../DatosKaggle/BuzzFeed/BuzzFeed_real_news_content.csv"
FAKE_PATH = "../DatosKaggle/BuzzFeed/BuzzFeed_fake_news_content.csv"
NEWS_PATH = "../DatosKaggle/BuzzFeed/BuzzFeedNews.txt"

# %% [markdown]
# El objetivo de este notebook es tomar el dataset de red bipartita y cambiar el valor de la columna news_id a un string.
# Mas puntualmente, mapear el id de la noticia a un hash unico.

# %% [markdown]
# ## Carga del dataset de Fake News Dataset

# %%
df_fake = pd.read_csv(FAKE_PATH)
df_real = pd.read_csv(REAL_PATH)

# %%
df_fake.head(n=1)
# Out:
#                id                                              title  \
# 0  Fake_1-Webpage  Proof The Mainstream Media Is Manipulating The...
#
#                                                 text  \
# 0  I woke up this morning to find a variation of ...
#
#                                                  url  \
# 0  http://www.addictinginfo.org/2016/09/19/proof-...
#
#                                              top_img          authors  \
# 0  http://addictinginfo.addictinginfoent.netdna-c...  Wendy Gittleson
#
#                          source              publish_date movies  \
# 0  http://www.addictinginfo.org  {'$date': 1474243200000}    NaN
#
#                                               images  \
# 0  http://i.imgur.com/JeqZLhj.png,http://addictin...
#
#                                       canonical_link  \
# 0  http://addictinginfo.com/2016/09/19/proof-the-...
#
#                                            meta_data
# 0  {"publisher": "Addicting Info | The Knowledge ...

# %%
df_real.head(n=1)
# Out:
#                id                                              title  \
# 0  Real_1-Webpage  Another Terrorist Attack in NYC…Why Are we STI...
#
#                                                 text  \
# 0  On Saturday, September 17 at 8:30 pm EST, an e...
#
#                                                  url  \
# 0  http://eaglerising.com/36942/another-terrorist...
#
#                                              top_img  \
# 0  http://eaglerising.com/wp-content/uploads/2016...
#
#                            authors                  source  \
# 0  View All Posts,Leonora Cravotta  http://eaglerising.com
#
#                publish_date movies  \
# 0  {'$date': 1474528230000}    NaN
#
#                                               images  \
# 0  http://constitution.com/wp-content/uploads/201...
#
#                                       canonical_link  \
# 0  http://eaglerising.com/36942/another-terrorist...
#
#                                            meta_data
# 0  {"description": "\u201cWe believe at this poin...

# %%
# La columna id de los dataframe Fake y Real tiene valores de este estilo: Fake_1-Webpage
# El objetivo es quedarnos con el valor numerico, en este caso 1 y eliminar los caracteres restantes.

def fix_id(news_id:str):
    news_id = news_id[5:]
    news_id = news_id[:-8]
    return int(news_id)

df_fake["id"] = df_fake["id"].apply(lambda x: int(fix_id(x)))
df_real["id"] = df_real["id"].apply(lambda x: int(fix_id(x)))

# %%
# Ordenamos los dataset (ya que no lo estan) y reseteamos los indices de los dataframes
df_fake = df_fake.sort_values(by=['id'], ascending=True).reset_index(drop=True)
df_real = df_real.sort_values(by=['id'], ascending=True).reset_index(drop=True)

# %% [markdown]
# Checkeamos los resultados

# %%
df_fake.head(n=1)
# Out:
#    id                                              title  \
# 0   1  Proof The Mainstream Media Is Manipulating The...
#
#                                                 text  \
# 0  I woke up this morning to find a variation of ...
#
#                                                  url  \
# 0  http://www.addictinginfo.org/2016/09/19/proof-...
#
#                                              top_img          authors  \
# 0  http://addictinginfo.addictinginfoent.netdna-c...  Wendy Gittleson
#
#                          source              publish_date movies  \
# 0  http://www.addictinginfo.org  {'$date': 1474243200000}    NaN
#
#                                               images  \
# 0  http://i.imgur.com/JeqZLhj.png,http://addictin...
#
#                                       canonical_link  \
# 0  http://addictinginfo.com/2016/09/19/proof-the-...
#
#                                            meta_data
# 0  {"publisher": "Addicting Info | The Knowledge ...

# %%
df_real.head(n=1)
# Out:
#    id                                              title  \
# 0   1  Another Terrorist Attack in NYC…Why Are we STI...
#
#                                                 text  \
# 0  On Saturday, September 17 at 8:30 pm EST, an e...
#
#                                                  url  \
# 0  http://eaglerising.com/36942/another-terrorist...
#
#                                              top_img  \
# 0  http://eaglerising.com/wp-content/uploads/2016...
#
#                            authors                  source  \
# 0  View All Posts,Leonora Cravotta  http://eaglerising.com
#
#                publish_date movies  \
# 0  {'$date': 1474528230000}    NaN
#
#                                               images  \
# 0  http://constitution.com/wp-content/uploads/201...
#
#                                       canonical_link  \
# 0  http://eaglerising.com/36942/another-terrorist...
#
#                                            meta_data
# 0  {"description": "\u201cWe believe at this poin...

# %% [markdown]
# ## Carga del dataset de Noticias

# %%
df_news = pd.read_table(NEWS_PATH, header=None, names=["news"])

# %% [markdown]
# ### Creacion de una nueva columna indicando el tipo de noticia

# %%
df_real['news_type'] = "Real"
df_fake['news_type'] = "Fake"

# %%
df_real.head(n=2)
# Out:
#    id                                              title  \
# 0   1  Another Terrorist Attack in NYC…Why Are we STI...
# 1   2  Hillary Clinton on police shootings: 'too many...
#
#                                                 text  \
# 0  On Saturday, September 17 at 8:30 pm EST, an e...
# 1  Story highlights "This, though, is certain: to...
#
#                                                  url  \
# 0  http://eaglerising.com/36942/another-terrorist...
# 1                              http://cnn.it/2cRxlv5
#
#                                              top_img  \
# 0  http://eaglerising.com/wp-content/uploads/2016...
# 1  http://i2.cdn.cnn.com/cnnnext/dam/assets/16091...
#
#                                  authors                  source  \
# 0        View All Posts,Leonora Cravotta  http://eaglerising.com
# 1  Mj Lee,Cnn National Politics Reporter           http://cnn.it
#
#                publish_date movies  \
# 0  {'$date': 1474528230000}    NaN
# 1                       NaN    NaN
#
#                                               images  \
# 0  http://constitution.com/wp-content/uploads/201...
# 1  http://i2.cdn.cnn.com/cnnnext/dam/assets/16091...
#
#                                       canonical_link  \
# 0  http://eaglerising.com/36942/another-terrorist...
# 1  http://www.cnn.com/2016/09/21/politics/hillary...
#
#                                            meta_data news_type
# 0  {"description": "\u201cWe believe at this poin...      Real
# 1  {"description": "Hillary Clinton kicked off a ...      Real

# %%
df_fake.head(n=2)
# Out:
#    id                                              title  \
# 0   1  Proof The Mainstream Media Is Manipulating The...
# 1   2  Declassified Docs Show That Obama Admin Create...
#
#                                                 text  \
# 0  I woke up this morning to find a variation of ...
# 1  Thanks in part to the declassification of Defe...
#
#                                                  url  \
# 0  http://www.addictinginfo.org/2016/09/19/proof-...
# 1  http://usherald.com/breaking-declassified-docs...
#
#                                              top_img          authors  \
# 0  http://addictinginfo.addictinginfoent.netdna-c...  Wendy Gittleson
# 1  http://usherald.com/wp-content/uploads/2015/05...      Bob Amoroso
#
#                          source              publish_date movies  \
# 0  http://www.addictinginfo.org  {'$date': 1474243200000}    NaN
# 1           http://usherald.com  {'$date': 1432650030000}    NaN
#
#                                               images  \
# 0  http://i.imgur.com/JeqZLhj.png,http://addictin...
# 1  http://usherald.com/wp-content/uploads/2015/02...
#
#                                       canonical_link  \
# 0  http://addictinginfo.com/2016/09/19/proof-the-...
# 1  http://usherald.com/breaking-declassified-docs...
#
#                                            meta_data news_type
# 0  {"publisher": "Addicting Info | The Knowledge ...      Fake
# 1  {"generator": "WordPress 4.8.1", "og": {"site_...      Fake

# %%
df_fake.index = df_fake.index + 91
df_fake.id = df_fake.id + 91
df_fake.head()
# Out:
#     id                                              title  \
# 91  92  Proof The Mainstream Media Is Manipulating The...
# 92  93  Declassified Docs Show That Obama Admin Create...
# 93  94  Why is it “RACIST” to Question Someone’s Birth...
# 94  95  HILLARY ON DISABLED CHILDREN During Easter Egg...
# 95  96        'Reporters' FLEE When Clintons Get EXPOSED!
#
#                                                  text  \
# 91  I woke up this morning to find a variation of ...
# 92  Thanks in part to the declassification of Defe...
# 93  The Democrats are using an intimidation tactic...
# 94  Dolly Kyle has written a scathing “tell all” b...
# 95  The Haitians in the audience have some newswor...
#
#                                                   url  \
# 91  http://www.addictinginfo.org/2016/09/19/proof-...
# 92  http://usherald.com/breaking-declassified-docs...
# 93  http://eaglerising.com/36841/why-is-it-racist-...
# 94  http://100percentfedup.com/hillary-on-disabled...
# 95  http://clashdaily.com/2016/09/watch-trump-visi...
#
#                                               top_img                 authors  \
# 91  http://addictinginfo.addictinginfoent.netdna-c...         Wendy Gittleson
# 92  http://usherald.com/wp-content/uploads/2015/05...             Bob Amoroso
# 93  http://eaglerising.com/wp-content/uploads/2016...          View All Posts
# 94  http://100percentfedup.com/wp-content/uploads/...                  Fed Up
# 95  http://clashdaily.com/wp-content/uploads/2016/...  Rich Witmer,Doug Giles
#
#                           source              publish_date  \
# 91  http://www.addictinginfo.org  {'$date': 1474243200000}
# 92           http://usherald.com  {'$date': 1432650030000}
# 93        http://eaglerising.com  {'$date': 1474243356000}
# 94    http://100percentfedup.com  {'$date': 1466439263000}
# 95         http://clashdaily.com  {'$date': 1474208802000}
#
#                                                movies  \
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
# 95  https://www.youtube.com/embed/x5IS6Ya005E?feat...
#
#                                                images  \
# 91  http://i.imgur.com/JeqZLhj.png,http://addictin...
# 92  http://usherald.com/wp-content/uploads/2015/02...
# 93  http://2lv0hm3wvpix464wwy2zh7d1.wpengine.netdn...
# 94  https://www.facebook.com/tr?id=157908891568640...
# 95  http://clashdaily.wpengine.netdna-cdn.com/wp-c...
#
#                                        canonical_link  \
# 91  http://addictinginfo.com/2016/09/19/proof-the-...
# 92  http://usherald.com/breaking-declassified-docs...
# 93  http://eaglerising.com/36841/why-is-it-racist-...
# 94  http://100percentfedup.com/hillary-on-disabled...
# 95  http://clashdaily.com/2016/09/watch-trump-visi...
#
#                                             meta_data news_type
# 91  {"publisher": "Addicting Info | The Knowledge ...      Fake
# 92  {"generator": "WordPress 4.8.1", "og": {"site_...      Fake
# 93  {"description": "There is evidence the birth c...      Fake
# 94  {"googlebot": "noimageindex", "generator": "Po...      Fake
# 95  {"googlebot": "noimageindex", "og": {"site_nam...      Fake

# %%
df_all_news = pd.concat([df_real, df_fake])
df_all_news.to_csv('news_id_title_type.csv', index = False, header=True, encoding='utf-8')

# %%
df_all_news.head(n=2)
# Out:
#    id                                              title  \
# 0   1  Another Terrorist Attack in NYC…Why Are we STI...
# 1   2  Hillary Clinton on police shootings: 'too many...
#
#                                                 text  \
# 0  On Saturday, September 17 at 8:30 pm EST, an e...
# 1  Story highlights "This, though, is certain: to...
#
#                                                  url  \
# 0  http://eaglerising.com/36942/another-terrorist...
# 1                              http://cnn.it/2cRxlv5
#
#                                              top_img  \
# 0  http://eaglerising.com/wp-content/uploads/2016...
# 1  http://i2.cdn.cnn.com/cnnnext/dam/assets/16091...
#
#                                  authors                  source  \
# 0        View All Posts,Leonora Cravotta  http://eaglerising.com
# 1  Mj Lee,Cnn National Politics Reporter           http://cnn.it
#
#                publish_date movies  \
# 0  {'$date': 1474528230000}    NaN
# 1                       NaN    NaN
#
#                                               images  \
# 0  http://constitution.com/wp-content/uploads/201...
# 1  http://i2.cdn.cnn.com/cnnnext/dam/assets/16091...
#
#                                       canonical_link  \
# 0  http://eaglerising.com/36942/another-terrorist...
# 1  http://www.cnn.com/2016/09/21/politics/hillary...
#
#                                            meta_data news_type
# 0  {"description": "\u201cWe believe at this poin...      Real
# 1  {"description": "Hillary Clinton kicked off a ...      Real

# %% [markdown]
# Guardamos el dataset solo con las columnas id, titlo y tipo de noticia

# %%
df_all_news[["id", "title", "news_type"]].to_csv('news_id_title_type.csv',  index = False, header=True, encoding='utf-8')

# %% [markdown]
# ## Carga de Dataset Noticias Usuarios

# %%
bipartite = pd.read_csv("../DatosKaggle/BuzzFeed/sample/BuzzFeedNewsUser_sample_20210815.csv")
bipartite.columns = ["news_id", "user_id"]
bipartite.head()
# Out:
#    news_id  user_id
# 0      140       10
# 1      150       11
# 2       21       41
# 3       42       51
# 4       51      114

# %%
# Checkeamos cuantas news_id unicas hay
print(f"Cantidad de id de noticias unicos: {len(set(bipartite['news_id']))}")
print(f"Cantidad de id de noticias en total: {len(bipartite['news_id'])}")
# Out:
# Cantidad de id de noticias unicos: 37
# Cantidad de id de noticias en total: 1314

# %%
# Hacemos coincidir el indice del dataset con el  mismo numero de id
df_all_news.index = df_all_news.index + 1

# %%
# Matcheamos news_id con news_title

title_name = []
title_id = []
fake_or_real = []
for index, row in bipartite.iterrows():
    id_ = row["news_id"]
    result = df_all_news["title"].loc[id_]
    news_type = df_all_news["news_type"].loc[id_]
    title_name.append(result)
    title_id.append(id_)
    fake_or_real.append(news_type)

# %%
bipartite["title"] = title_name
bipartite["news_type"] = fake_or_real

# %% [markdown]
# Checkeamos la distribucion de fake y real news

# %%
bipartite["news_type"].value_counts()
# Out:
# Real    696
# Fake    618
# Name: news_type, dtype: int64

# %%
# Asociamos el news_id a un hash unico (esto es porque R no puede cargar una red y distinguir entre dos tipos de nodos
# si los tipos de datos son iguales. Por eso no podemos usar un id numerico y tenemos que usar un hash)

news_id_to_hash = {}
title_id = set(title_id)
news_id_to_hash = {id: uuid.uuid4().hex[:6].upper() for id in title_id}

# %%
def get_title_hash(id: int):
    return news_id_to_hash.get(id)

bipartite['news_title_hash'] = bipartite['news_id'].apply(lambda x: get_title_hash(x))
bipartite.head()
# Out:
#    news_id  user_id                                              title  \
# 0      140       10  Federal Agents Make Massive Discovery at South...
# 1      150       11  ABC Reveals Trump Paid "Hundreds Of Millions" ...
# 2       21       41  Anthony Weiner Under Federal Investigation for...
# 3       42       51            National poll: Clinton leads Trump by 6
# 4       51      114  Trump labels Clinton 'weak and ineffective' in...
#
#   news_type news_title_hash
# 0      Fake          A8E571
# 1      Fake          F466AA
# 2      Real          9C8FAF
# 3      Real          B4EA27
# 4      Real          229D27

# %%
len(set(bipartite['news_title_hash']))
# Out:
# 37

# %% [markdown]
# Guardamos el dataset

# %%
bipartite.to_csv("../DatosKaggle/BuzzFeed/sample/BipartiteUserNewsComplete_20210815.csv", index = False, encoding='utf-8-sig')

# %% [markdown]
# Deleting news_id column as we don´t need it

# %%
del bipartite['news_id']
del bipartite['title']
del bipartite['news_type']

bipartite.head()
# Out:
#    user_id news_title_hash
# 0       10          A8E571
# 1       11          F466AA
# 2       41          9C8FAF
# 3       51          B4EA27
# 4      114          229D27

# %%
# Save bipartite dataset with news name and user id to a csv
bipartite.to_csv("../DatosKaggle/BuzzFeed/sample/BuzzFeedNewsUser_newshash_20210815.csv", index = False, encoding='utf-8-sig')
